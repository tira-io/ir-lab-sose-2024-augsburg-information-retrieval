# %% [markdown]
# # Operations, Transformers and Pipelines
#
# This notebook goes a little into detail about the section Transformer-pipelines in the dataset_analysis.ipynb Notebook

# %% [markdown]
# ## Setup
#
# Libraries and Imports

# %%
# If using Google Colab:
#!pip3 install tira ir-datasets python-terrier

# %%
# Imports
from tira.third_party_integrations import ensure_pyterrier_is_loaded, persist_and_normalize_run
from tira.third_party_integrations import ir_datasets
from tira.rest_api_client import Client
import pyterrier as pt

import pandas as pd
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
#pd.set_option("display.max_rows", None)
pd.set_option("display.precision", 4)

# %%
# Create a REST client to the TIRA platform for retrieving the pre-indexed data.
ensure_pyterrier_is_loaded()
tira = Client()
# Out:
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %% [markdown]
# ## Indexing
#
# For all retrieval related stuff in pyterrier the index is used.

# %%
# get the dataset
pt_dataset = pt.get_dataset('irds:ir-lab-sose-2024/ir-acl-anthology-20240504-training')

# (pre-built) PyTerrier index loaded from TIRA
index = tira.pt.index('ir-lab-sose-2024/tira-ir-starter/Index (tira-ir-starter-pyterrier)', pt_dataset)

# %% [markdown]
# ## Transformers & Operations

# %%
tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
tf = pt.BatchRetrieve(index, wmodel="Tf")

scores = tf( pt_dataset.get_topics(variant="title").head(1) ).head(10)
print(scores)
# Out:
#   qid   docid                                          docno  rank  score  \
# 0   1   73688               2001.sigirconf_workshop-2001w1.0     0  128.0
# 1   1  122235  1989.sigirjournals_journal-ir0volumeA23A34.11     1   74.0
# 2   1   83452                1997.sigirconf_conference-97.33     2   72.0
# 3   1   76558                      2000.clef_workshop-2000.0     3   71.0
# 4   1  126292             2019.tois_journal-ir0volumeA37A1.2     4   50.0
# 5   1   84107              2003.sigirconf_conference-2003.49     5   46.0
# 6   1  101146                   2010.spire_conference-2010.0     6   46.0
# 7   1  122479   2010.sigirjournals_journal-ir0volumeA44A2.15     7   45.0
# 8   1   82479                1998.sigirconf_conference-98.22     8   41.0
# 9   1   82496                1998.sigirconf_conference-98.39     9   41.0
#
#                                       query
# 0  retrieval system improving effectiveness
# 1  retrieval system improving effectiveness
# 2  retrieval system improving effectiveness
# 3  retrieval system improving effectiveness
# 4  retrieval system improving effectiveness
# 5  retrieval system improving effectiveness
# 6  retrieval system improving effectiveness
# 7  retrieval system improving effectiveness
# 8  retrieval system improving effectiveness
# 9  retrieval system improving effectiveness

# %% [markdown]
# ## Pipeline Construction

# %% [markdown]
# ## Beispielhafter Versuchsaufbau

# %%
from sklearn.model_selection import train_test_split


# Imports
from tira.third_party_integrations import ensure_pyterrier_is_loaded, persist_and_normalize_run
from tira.third_party_integrations import ir_datasets
from tira.rest_api_client import Client
import pyterrier as pt

import pandas as pd
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
#pd.set_option("display.max_rows", None)
pd.set_option("display.precision", 4)

# Create a REST client to the TIRA platform for retrieving the pre-indexed data.
ensure_pyterrier_is_loaded()
tira = Client()
# Out:
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %%
RANK_CUTOFF = 10
SEED = 10

dataset = pt.get_dataset('irds:ir-lab-sose-2024/ir-acl-anthology-20240504-training')
#dataset = ir_datasets.load("ir-lab-sose-2024/ir-acl-anthology-20240504-training")

topics = dataset.get_topics() # variant??
qrels = dataset.get_qrels()

train_val_topics, test_topics = train_test_split(topics, test_size=15, random_state=SEED)
train_topics, val_topics = train_test_split(train_val_topics, test_size=15, random_state=SEED)
# Out:
# There are multiple query fields available: ('text', 'title', 'query', 'description', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.

# %%
# FEATURES

index = tira.pt.index('ir-lab-sose-2024/tira-ir-starter/Index (tira-ir-starter-pyterrier)', dataset)

bm25 = pt.BatchRetrieve(index, wmodel="BM25")
sdm = pt.rewrite.SDM()
qe = pt.rewrite.Bo1QueryExpansion(index)

ltr_feats1 = (bm25 % RANK_CUTOFF) >> pt.text.get_text(dataset, ["doc_id", "text"]) >> (
    pt.transformer.IdentityTransformer()
    ** # sequential dependence
    (sdm >> bm25)
    #** # score of text for query 'tomato'
    #(pt.apply.query(lambda row: 'tomato') >> bm25)
    ** # score of title (not originally indexed)
    (pt.text.scorer(body_attr="text", takes='docs', wmodel='BM25')) 
#    ** # date 2020
#    (pt.apply.doc_score(lambda row: int("2020" in row["date"])))
    ** # has doi
    (pt.apply.doc_score(lambda row: int( row["doc_id"] is not None and len(row["doc_id"]) > 0) ))
    ** # abstract coordinate match
    pt.BatchRetrieve(index, wmodel="CoordinateMatch")
)

# %%
res = ltr_feats1.search("neural")
res = res[["qid", "docid", "docno", "rank", "score", "query", "doc_id", "features"]]
res
# Out:
# 16:23:40.065 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
#   qid   docid                              docno  rank   score   query  \
# 0   1   46911                           N16-1065     0  6.7668  neural
# 1   1   29197                           W17-4914     1  6.6466  neural
# 2   1   42273                           P18-1223     2  6.5876  neural
# 3   1   39667                           P18-2060     3  6.5553  neural
# 4   1  108626  2005.wwwconf_conference-2005si.54     4  6.5400  neural
# 5   1   30184                           N18-1055     5  6.5350  neural
# 6   1   91713      2020.ecir_conference-20202.58     6  6.5232  neural
# 7   1    4564                           C18-1266     7  6.5120  neural
# 8   1   66623                        2021.cl-1.6     8  6.5112  neural
# 9   1   42858                           W17-4123     9  6.5097  neural
#
#                               doc_id  \
# 0                           N16-1065
# 1                           W17-4914
# 2                           P18-1223
# 3                           P18-2060
# 4  2005.wwwconf_conference-2005si.54
# 5                           N18-1055
# 6      2020.ecir_conference-20202.58
# 7                           C18-1266
# 8                        2021.cl-1.6
# 9                           W17-4123
#
#                                                                                 features
# 0  [6.7668194554010475, 6.7668194554010475, -8.459695810623721, 1.0, 6.7668194554010475]
# 1     [6.646604380515833, 6.646604380515833, -8.334060219255585, 1.0, 6.646604380515833]
# 2     [6.587611735634998, 6.587611735634998, -8.265185567105398, 1.0, 6.587611735634998]
# 3     [6.555326659823115, 6.555326659823115, -8.209298568342081, 1.0, 6.555326659823115]
# 4      [6.540047885527931, 6.540047885527931, -8.19331749741392, 1.0, 6.540047885527931]
# 5     [6.535039286684509, 6.535039286684509, -8.226413902194334, 1.0, 6.535039286684509]
# 6     [6.523177539953064, 6.523177539953064, -8.188358290973635, 1.0, 6.523177539953064]
# 7  [6.5120015894951395, 6.5120015894951395, -8.197809577415388, 1.0, 6.5120015894951395]
# 8  [6.5111804822252495, 6.5111804822252495, -8.184819674598971, 1.0, 6.5111804822252495]
# 9     [6.509703010835169, 6.509703010835169, -8.161541294071368, 1.0, 6.509703010835169]

# %%
# Define Pipeline with >> operator
# this is called a composition

pipeline = tf >> tfidf

query = pt_dataset.get_topics(variant="title").head(1)
print(query)

#print(tf(query).head(50))
#print( pipeline( pt_dataset.get_topics(variant="title").head(1) ).head(10) )
# Out:
#   qid                                     query
# 0   1  retrieval system improving effectiveness
#    qid   docid                                          docno  rank  score  \
# 0    1   73688               2001.sigirconf_workshop-2001w1.0     0  128.0
# 1    1  122235  1989.sigirjournals_journal-ir0volumeA23A34.11     1   74.0
# 2    1   83452                1997.sigirconf_conference-97.33     2   72.0
# 3    1   76558                      2000.clef_workshop-2000.0     3   71.0
# 4    1  126292             2019.tois_journal-ir0volumeA37A1.2     4   50.0
# 5    1   84107              2003.sigirconf_conference-2003.49     5   46.0
# 6    1  101146                   2010.spire_conference-2010.0     6   46.0
# 7    1  122479   2010.sigirjournals_journal-ir0volumeA44A2.15     7   45.0
# 8    1   82479                1998.sigirconf_conference-98.22     8   41.0
# 9    1   82496                1998.sigirconf_conference-98.39     9   41.0
# 10   1  122484   2010.sigirjournals_journal-ir0volumeA44A2.20    10   41.0
# 11   1   81703                1995.sigirconf_conference-95.30    11   38.0
# 12   1   82102             2007.sigirconf_conference-2007.212    12   38.0
# 13   1   96540                   2001.cikm_conference-2001.28    13   34.0
# 14   1  101710                   2013.ictir_conference-2013.3    14   34.0
# 15   1   83395             2016.sigirconf_conference-2016.211    15   33.0
# 16   1   81655             2018.sigirconf_conference-2018.234    16   31.0
# 17   1  122130    2012.sigirjournals_journal-ir0volumeA46A1.9    17   31.0
# 18   1  122478   2010.sigirjournals_journal-ir0volumeA44A2.14    18   31.0
# 19   1  126875             2000.tois_journal-ir0volumeA18A1.0    19   31.0
# 20   1   75653                     2003.clef_workshop-2003.37    20   30.0
# 21   1   82513                1998.sigirconf_conference-98.56    21   30.0
# 22   1  121718    1997.sigirjournals_journal-ir0volumeA31A1.7    22   29.0
# 23   1  122271   2011.sigirjournals_journal-ir0volumeA45A2.15    23   29.0
# 24   1   83455                1997.sigirconf_conference-97.36    24   28.0
# 25   1   83987                1985.sigirconf_conference-85.25    25   28.0
# 26   1   84123              2003.sigirconf_conference-2003.65    26   28.0
# 27   1  122252   2011.sigirjournals_journal-ir0volumeA45A1.13    27   27.0
# 28   1  122481   2010.sigirjournals_journal-ir0volumeA44A2.17    28   27.0
# 29   1  126531             2017.tois_journal-ir0volumeA36A2.8    29   27.0
# 30   1   75134                   2005.clef_workshop-2005w.119    30   26.0
# 31   1   82250             2010.sigirconf_conference-2010.138    31   26.0
# 32   1   80665             2014.sigirconf_conference-2014.219    32   25.0
# 33   1   81664             2018.sigirconf_conference-2018.243    33   25.0
# 34   1   82229             2010.sigirconf_conference-2010.117    34   25.0
# 35   1   83691             2017.sigirconf_conference-2017.231    35   25.0
# 36   1   90115                    2012.airs_conference-2012.0    36   25.0
# 37   1   77585                  2012.cikm_workshop-2012pikm.9    37   24.0
# 38   1   80658             2014.sigirconf_conference-2014.212    38   24.0
# 39   1   81726                1971.sigirconf_conference-71.10    39   24.0
# 40   1   83708             2017.sigirconf_conference-2017.248    40   24.0
# 41   1  122632   2018.sigirjournals_journal-ir0volumeA52A2.22    41   24.0
# 42   1  125153              2008.ipm_journal-ir0volumeA44A3.9    42   24.0
# 43   1   76197                   2006.clef_workshop-2006w.137    43   23.0
# 44   1   77772                 2013.cikm_workshop-2013esair.5    44   23.0
# 45   1   80668             2014.sigirconf_conference-2014.222    45   23.0
# 46   1   81645             2018.sigirconf_conference-2018.224    46   23.0
# 47   1   83768              2000.sigirconf_conference-2000.52    47   23.0
# 48   1  114506             2018.tweb_journal-ir0volumeA12A1.3    48   23.0
# 49   1   81884             2006.sigirconf_conference-2006.147    49   22.0
#
#                                        query
# 0   retrieval system improving effectiveness
# 1   retrieval system improving effectiveness
# 2   retrieval system improving effectiveness
# 3   retrieval system improving effectiveness
# 4   retrieval system improving effectiveness
# 5   retrieval system improving effectiveness
# 6   retrieval system improving effectiveness
# 7   retrieval system improving effectiveness
# 8   retrieval system improving effectiveness
# 9   retrieval system improving effectiveness
# 10  retrieval system improving effectiveness
# 11  retrieval system improving effectiveness
# 12  retrieval system improving effectiveness
# 13  retrieval system improving effectiveness
# 14  retrieval system improving effectiveness
# 15  retrieval system improving effectiveness
# 16  retrieval system improving effectiveness
# 17  retrieval system improving effectiveness
# 18  retrieval system improving effectiveness
# 19  retrieval system improving effectiveness
# 20  retrieval system improving effectiveness
# 21  retrieval system improving effectiveness
# 22  retrieval system improving effectiveness
# 23  retrieval system improving effectiveness
# 24  retrieval system improving effectiveness
# 25  retrieval system improving effectiveness
# 26  retrieval system improving effectiveness
# 27  retrieval system improving effectiveness
# 28  retrieval system improving effectiveness
# 29  retrieval system improving effectiveness
# 30  retrieval system improving effectiveness
# 31  retrieval system improving effectiveness
# 32  retrieval system improving effectiveness
# 33  retrieval system improving effectiveness
# 34  retrieval system improving effectiveness
# 35  retrieval system improving effectiveness
# 36  retrieval system improving effectiveness
# 37  retrieval system improving effectiveness
# 38  retrieval system improving effectiveness
# 39  retrieval system improving effectiveness
# 40  retrieval system improving effectiveness
# 41  retrieval system improving effectiveness
# 42  retrieval system improving effectiveness
# 43  retrieval system improving effectiveness
# 44  retrieval system improving effectiveness
# 45  retrieval system improving effectiveness
# 46  retrieval system improving effectiveness
# 47  retrieval system improving effectiveness
# 48  retrieval system improving effectiveness
# 49  retrieval system improving effectiveness

# %%
# RANKER

tf_at_10 = tf( pt_dataset.get_topics(variant="title").head(1) ).head(100)
tfidf_at_10 = tfidf( pt_dataset.get_topics(variant="title").head(1) ).head(100)
#print(tf_at_10)
#print(tfidf_at_10)

# %%
best_tf_docids = set(tf_at_10["docid"].values)
best_tfidf_docids = set(tfidf_at_10["docid"].values)
#print(best_tf_docids)
#print(best_tfidf_docids)

intersection = best_tf_docids & best_tfidf_docids
print(intersection)
# Out:
# {90115, 83984, 83987, 59419, 82460, 29725, 112161, 82465, 80937, 74282, 82479, 82486, 83000, 123967, 82496, 84545, 126531, 121932, 82513, 82528, 88166, 122478, 122479, 122481, 122484, 126596, 94858, 84107, 84123, 86693, 113323, 82102, 82104, 101568, 106180, 209, 124115, 125153, 50402, 83691, 81643, 81645, 106229, 94453, 81655, 83708, 81664, 83712, 88834, 122117, 122632, 76558, 83728, 77585, 122130, 80658, 93970, 122131, 122133, 80665, 101146, 96540, 80668, 81703, 82229, 77621, 83765, 83768, 83770, 81726, 82250, 114506, 101710, 126292, 123748, 79731, 121718, 122235, 75134, 124799, 75653, 92043, 122252, 82316, 122253, 82327, 126875, 122271, 76197, 81318, 83877, 80304, 83395, 82374, 77772, 101842, 73688, 81884, 83452, 83455}
# {74247, 82952, 94732, 126479, 90655, 82472, 87595, 82475, 114223, 111672, 82490, 92224, 80449, 101445, 86088, 53327, 17496, 82538, 84081, 84593, 124023, 83075, 75400, 94858, 94859, 82580, 83604, 79515, 94364, 123051, 96429, 73906, 111285, 82102, 74431, 111300, 94415, 80592, 125137, 76495, 94417, 112862, 125153, 46819, 85224, 111339, 5868, 111345, 74485, 91391, 124164, 11525, 74513, 124187, 74020, 121640, 123691, 119601, 101686, 116546, 75074, 83780, 73542, 116566, 124773, 126826, 83313, 84337, 125817, 124799, 124801, 96648, 84876, 110990, 81298, 75156, 74650, 78234, 68007, 81840, 71602, 91577, 81855, 110017, 123338, 80845, 64461, 47570, 80851, 94173, 80862, 80355, 124899, 37861, 73702, 74730, 81397, 83449, 81915, 78846}
# {125153, 94858, 82102, 124799}
